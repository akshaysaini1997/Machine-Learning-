# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\hp\\Downloads\\newplacementdata.csv" , usecols = ['cgpa' , 'placement_exam_marks'])
df
# Out:
#      cgpa  placement_exam_marks
# 0    7.19                    26
# 1    7.46                    38
# 2    7.54                    40
# 3    6.42                     8
# 4    7.23                    17
# ..    ...                   ...
# 995  8.87                    44
# 996  9.12                    65
# 997  4.89                    34
# 998  8.62                    46
# 999  4.90                    10
#
# [1000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['placement_exam_marks'])
plt.xlabel('cgpa')
plt.ylabel('placement_exam_marks')
# Out:
# Text(0, 0.5, 'placement_exam_marks')

# %%
x = df.iloc[: , 0:1]
y = df.iloc[: , -1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2, random_state= 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test , y_pred )
# Out:
# 0.0011019705709978123

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31.72042454])

# %%
plt.scatter(df['cgpa'] , df['placement_exam_marks'])
plt.plot(x_train, lr.predict(x_train),color= 'red')
plt.xlabel('cgpa')
plt.ylabel('placement_exam_marks')
# Out:
# Text(0, 0.5, 'placement_exam_marks')

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.0011019705709978123

# %%
import seaborn as sns

# %%
sns.distplot(df['cgpa'])
sns.distplot(df['placement_exam_marks'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='placement_exam_marks', ylabel='Density'>

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt= PowerTransformer(method = 'yeo-johnson' )
new = pt.fit_transform(x_train)
new1 = pt.transform(x_test)
new_x_train = pd.DataFrame(new,columns = x_train.columns)
new_x_train
new_x_test = pd.DataFrame(new1, columns= x_test.columns)

# %%
sns.distplot(new)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
y_pred = lr.predict(new_x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# -0.002920194231025519

# %% [markdown]
# # new data

# %%
df = pd.read_csv('C:\\Users\\hp\\Downloads\\Salary_Data.csv')
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x = df.drop(columns = ['Salary'] , axis = 1)
y= df['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Salary'], df['YearsExperience'])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred , y_test)
# Out:
# 0.8961838737587328

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
m= lr.coef_

# %%
b = lr.intercept_

# %%
y = m*1.1+b
y
# Out:
# array([35687.77986711])

# %% [markdown]
# # new data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\hp\\Downloads\\placement.csv" , usecols = ['cgpa','resume_score'])
df
# Out:
#     cgpa  resume_score
# 0   8.14          6.52
# 1   6.17          5.17
# 2   8.27          8.86
# 3   6.88          7.27
# 4   7.52          7.30
# ..   ...           ...
# 95  6.33          6.38
# 96  8.23          7.76
# 97  6.65          7.78
# 98  8.14          5.63
# 99  6.09          6.61
#
# [100 rows x 2 columns]

# %%
x=df.drop(columns = ['cgpa'] , axis = 1)
x
y=df['cgpa']
y
# Out:
# 0     8.14
# 1     6.17
# 2     8.27
# 3     6.88
# 4     7.52
#       ...
# 95    6.33
# 96    8.23
# 97    6.65
# 98    8.14
# 99    6.09
# Name: cgpa, Length: 100, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'] , df['resume_score'])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred , y_test)
# Out:
# -5469.820730395192

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.9698603])

# %%
# plt.scatter(df['cgpa'] , df['resume_score'])
# plt.scatter(x_train, lr.predict(x_train) , color='red')

# %%
y_pred = lr.predict(x_test)
r2_score(y_pred,y_test)
# Out:
# -5469.820730395192

# %%
y_pred = lr.predict(x_test)
r2_score( y_pred,y_test)
# Out:
# -5469.820730395192
